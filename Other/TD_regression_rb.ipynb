# %%
import pandas as pd
import nflfastpy as nfl
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
df = pd.DataFrame()

for x in range(2015,2022):
    yearly_df = nfl.load_pbp_data(x)
    df = pd.concat([df, yearly_df])

# %%
df.shape
# Out:
# (289707, 372)

# %%
for column in df.columns:
    if 'rush' in column:
        print(column)
    elif 'distance' in column:
        print(column)
    elif 'yardline' in column:
        print(column)
    elif 'two' in column:
        print(column)
# Out:
# yardline_100
# kick_distance
# two_point_conv_result
# two_point_conversion_prob
# total_home_rush_epa
# total_away_rush_epa
# total_home_rush_wpa
# total_away_rush_wpa
# first_down_rush
# rush_attempt
# rush_touchdown
# two_point_attempt
# lateral_rush
# rusher_player_id
# rusher_player_name
# rushing_yards
# lateral_rusher_player_id
# lateral_rusher_player_name
# lateral_rushing_yards
# defensive_two_point_attempt
# defensive_two_point_conv
# rusher
# rusher_jersey_number
# rush
# rusher_id

# %%
rushing_df_filter = (df['rush_attempt'] == 1) & (df['two_point_attempt'] == 0)

rushing_df = df.loc[rushing_df_filter, ['rush_attempt', 'rush_touchdown', 'yardline_100']]

prob_rush_df = rushing_df.groupby('yardline_100')['rush_touchdown'].value_counts(normalize=True)
"""
Grouping by yardline of where each rush attempt began and then using value_counts to count if the attempt resulted in a touchdown.
Within the value_counts, the argument normalize is set to True, allowing for calculation of the proportion of rush attempts that 
result in touchdowns from each yardline. Doing this transforms the dataframe into a series so we must convert it back to a dataframe.
"""
# prob_rush_df = prob_rush_df.to_frame(name = 'probability_of_td')
prob_rush_df = pd.DataFrame({
    'probability_of_touchdown': prob_rush_df.values
}, index=prob_rush_df.index).reset_index()
prob_rush_df.head()
# Out:
#    yardline_100  rush_touchdown  probability_of_touchdown
# 0           1.0             1.0                  0.564392
# 1           1.0             0.0                  0.435608
# 2           2.0             0.0                  0.565806
# 3           2.0             1.0                  0.434194
# 4           3.0             0.0                  0.662411

# %%
prob_rush_df = prob_rush_df.loc[prob_rush_df['rush_touchdown'] == 1, ['yardline_100', 'probability_of_touchdown']].reset_index()
prob_rush_df = prob_rush_df.drop('index', axis=1)
prob_rush_df.head()
# Out:
#    yardline_100  probability_of_touchdown
# 0           1.0                  0.564392
# 1           2.0                  0.434194
# 2           3.0                  0.337589
# 3           4.0                  0.295552
# 4           5.0                  0.228758

# %%
prob_rush_df.shape
# Out:
# (92, 2)

# %%
# plt.plot(data=prob_rush_df, x='yardline_100', y='probability_of_touchdown')
# plt.title('Probability of scoring a rushing TD on an attempt X yds from endzone')
# plt.xlabel('Distance from endzone')

prob_rush_df.plot(x='yardline_100', y='probability_of_touchdown')
# Out:
# <AxesSubplot:xlabel='yardline_100'>

# %%
df_2021 = nfl.load_pbp_data(2021)
df_2021.head()
# Out:
#    play_id          game_id  old_game_id home_team away_team season_type  \
# 0        1  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 1       40  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 2       55  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 3       76  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 4      100  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
#
#    week posteam posteam_type defteam  ... out_of_bounds  home_opening_kickoff  \
# 0     1     NaN          NaN     NaN  ...             0                     1
# 1     1     TEN         home     ARI  ...             0                     1
# 2     1     TEN         home     ARI  ...             0                     1
# 3     1     TEN         home     ARI  ...             0                     1
# 4     1     TEN         home     ARI  ...             0                     1
#
#      qb_epa  xyac_epa  xyac_mean_yardage  xyac_median_yardage xyac_success  \
# 0       NaN       NaN                NaN                  NaN          NaN
# 1  0.000000       NaN                NaN                  NaN          NaN
# 2 -1.399805       NaN                NaN                  NaN          NaN
# 3  0.032412  1.165133           5.803177                  4.0     0.896654
# 4 -1.532898  0.256036           4.147637                  2.0     0.965009
#
#     xyac_fd     xpass    pass_oe
# 0       NaN       NaN        NaN
# 1       NaN       NaN        NaN
# 2       NaN  0.491433 -49.143299
# 3  0.125098  0.697346  30.265415
# 4  0.965009  0.978253   2.174652
#
# [5 rows x 372 columns]

# %%
roster_df = nfl.load_roster_data(2021)
roster_df.head()
# Out:
#    season team position depth_chart_position  jersey_number  status  \
# 0    2021  ARI       CB                  RCB              7  Active
# 1    2021  ARI       CB                  LCB             21  Active
# 2    2021  ARI       CB                  RCB             33  Active
# 3    2021  ARI       CB                  NaN             39  Active
# 4    2021  ARI       CB                  NaN             24  Active
#
#           full_name first_name  last_name  birth_date  ...    espn_id  \
# 0      Byron Murphy      Byron     Murphy  1998-01-18  ...  4038999.0
# 1     Breon Borders      Breon    Borders  1995-07-22  ...  3048663.0
# 2  Antonio Hamilton    Antonio   Hamilton  1993-01-24  ...  3056354.0
# 3    Jace Whittaker       Jace  Whittaker  1995-07-16  ...  3821572.0
# 4  Bashaud Breeland    Bashaud   Breeland  1992-01-30  ...    16890.0
#
#                           sportradar_id yahoo_id rotowire_id   pff_id  \
# 0  c025b513-9431-4097-bc25-9777bf08f846  31865.0     13560.0  44027.0
# 1  d0fa2103-69a1-4ed0-a3cd-4eb8d5e342c2  30623.0     12097.0  39398.0
# 2  9bc107dc-1920-49db-b009-436d1a77955d  29957.0     11518.0  11353.0
# 3  528bf5c9-1d23-40c3-adda-df21f8f0e2ab  33089.0     14793.0  50465.0
# 4  ba905b34-8412-4553-9055-3460368cc608  27630.0      9648.0   8737.0
#
#      pfr_id fantasy_data_id  sleeper_id  years_exp  \
# 0  MurpBy00         20888.0        5864        3.0
# 1  BordBr00         19300.0        4439        5.0
# 2  HamiAn01         18658.0        3838        6.0
# 3  WhitJa05         22171.0        7169        2.0
# 4  BreeBa00         16407.0        2091        8.0
#
#                                         headshot_url
# 0  https://static.www.nfl.com/image/private/f_aut...
# 1  https://static.www.nfl.com/image/private/f_aut...
# 2  https://static.www.nfl.com/image/private/f_aut...
# 3  https://static.www.nfl.com/image/private/f_aut...
# 4  https://static.www.nfl.com/image/private/f_aut...
#
# [5 rows x 25 columns]

# %%
rb_roster_df = roster_df.loc[roster_df['position'] == 'RB']['gsis_id']

rb_roster_df.head()
# Out:
# 60    00-0034331
# 61    00-0034681
# 62    00-0036383
# 63    00-0033553
# 64    00-0035825
# Name: gsis_id, dtype: object

# %%
from nflfastpy.utils import convert_to_gsis_id
from nflfastpy import default_headshot

rush_2021_df = df_2021.loc[df_2021['rush_attempt']== 1, ['rusher_id','rusher_player_name','rush_attempt', 'rush_touchdown', 'yardline_100']]
rush_2021_df = rush_2021_df.loc[rush_2021_df['rusher_id'].notnull()]
rush_2021_df['gsis_id'] = rush_2021_df['rusher_id'].apply(convert_to_gsis_id)
rush_2021_df = rush_2021_df.loc[rush_2021_df['rusher_id'].isin(rb_roster_df)]
rush_2021_df.head()
# Out:
#      rusher_id rusher_player_name  rush_attempt  rush_touchdown  yardline_100  \
# 2   00-0032764            D.Henry           1.0             0.0          75.0
# 10  00-0034681          C.Edmonds           1.0             0.0           9.0
# 18  00-0032764            D.Henry           1.0             0.0          80.0
# 28  00-0032764            D.Henry           1.0             0.0          75.0
# 29  00-0032764            D.Henry           1.0             0.0          73.0
#
#    gsis_id
# 2
# 10
# 18
# 28
# 29

# %%
rush_2021_df = rush_2021_df.merge(prob_rush_df, on = 'yardline_100', how = 'left')

rush_2021_df.head(20)
# Out:
#      rusher_id rusher_player_name  rush_attempt  rush_touchdown  yardline_100  \
# 0   00-0032764            D.Henry           1.0             0.0          75.0
# 1   00-0034681          C.Edmonds           1.0             0.0           9.0
# 2   00-0032764            D.Henry           1.0             0.0          80.0
# 3   00-0032764            D.Henry           1.0             0.0          75.0
# 4   00-0032764            D.Henry           1.0             0.0          73.0
# 5   00-0034681          C.Edmonds           1.0             0.0          65.0
# 6   00-0032764            D.Henry           1.0             0.0          68.0
# 7   00-0032764            D.Henry           1.0             0.0          69.0
# 8   00-0033553           J.Conner           1.0             0.0          45.0
# 9   00-0034681          C.Edmonds           1.0             0.0          42.0
# 10  00-0033553           J.Conner           1.0             0.0          29.0
# 11  00-0034681          C.Edmonds           1.0             0.0          25.0
# 12  00-0032764            D.Henry           1.0             0.0          63.0
# 13  00-0032764            D.Henry           1.0             0.0           1.0
# 14  00-0032764            D.Henry           1.0             0.0           1.0
# 15  00-0034681          C.Edmonds           1.0             0.0          57.0
# 16  00-0033553           J.Conner           1.0             0.0          45.0
# 17  00-0033553           J.Conner           1.0             0.0          19.0
# 18  00-0033553           J.Conner           1.0             0.0           8.0
# 19  00-0034681          C.Edmonds           1.0             0.0          84.0
#
#    gsis_id  probability_of_touchdown
# 0                           0.002249
# 1                           0.079480
# 2                           0.001558
# 3                           0.002249
# 4                           0.000837
# 5                           0.002581
# 6                           0.004598
# 7                           0.002793
# 8                           0.003247
# 9                           0.004077
# 10                          0.008630
# 11                          0.012195
# 12                          0.003544
# 13                          0.564392
# 14                          0.564392
# 15                          0.003353
# 16                          0.003247
# 17                          0.031686
# 18                          0.143654
# 19                          0.002890

# %%
rush_2021_df = rush_2021_df.drop('gsis_id', axis=1)

rush_2021_df.head()
# Out:
#     rusher_id rusher_player_name  rush_attempt  rush_touchdown  yardline_100  \
# 0  00-0032764            D.Henry           1.0             0.0          75.0
# 1  00-0034681          C.Edmonds           1.0             0.0           9.0
# 2  00-0032764            D.Henry           1.0             0.0          80.0
# 3  00-0032764            D.Henry           1.0             0.0          75.0
# 4  00-0032764            D.Henry           1.0             0.0          73.0
#
#    probability_of_touchdown
# 0                  0.002249
# 1                  0.079480
# 2                  0.001558
# 3                  0.002249
# 4                  0.000837

# %%
rush_2021_df = rush_2021_df.rename(columns={'rusher_id':'gsis_id'})

rush_2021_df.head()
# Out:
#       gsis_id rusher_player_name  rush_attempt  rush_touchdown  yardline_100  \
# 0  00-0032764            D.Henry           1.0             0.0          75.0
# 1  00-0034681          C.Edmonds           1.0             0.0           9.0
# 2  00-0032764            D.Henry           1.0             0.0          80.0
# 3  00-0032764            D.Henry           1.0             0.0          75.0
# 4  00-0032764            D.Henry           1.0             0.0          73.0
#
#    probability_of_touchdown
# 0                  0.002249
# 1                  0.079480
# 2                  0.001558
# 3                  0.002249
# 4                  0.000837

# %%
rush_2021_df = rush_2021_df.groupby('gsis_id', as_index=False).agg({
    'rusher_player_name': 'first', 'rush_touchdown': 'sum', 'probability_of_touchdown': 'sum'
}).rename({
    'probability_of_touchdown':'expected_touchdowns', 'rush_touchdown': 'season_rush_td_total'
}, axis=1)

rush_2021_df['positive_regression'] = rush_2021_df['season_rush_td_total'] < rush_2021_df['expected_touchdowns']
rush_2021_df['delta'] = rush_2021_df.apply(
    lambda x: abs(x.expected_touchdowns - x.season_rush_td_total), axis=1
)

rush_2021_df.sort_values(by='expected_touchdowns', ascending=False).head()
# Out:
#         gsis_id rusher_player_name  season_rush_td_total  expected_touchdowns  \
# 110  00-0036223           J.Taylor                  18.0            16.903730
# 46   00-0033897            J.Mixon                  14.0            12.959401
# 39   00-0033553           J.Conner                  16.0            11.979580
# 95   00-0035657           D.Harris                  15.0            10.182510
# 33   00-0033045          E.Elliott                  10.0            10.059096
#
#      positive_regression     delta
# 110                False  1.096270
# 46                 False  1.040599
# 39                 False  4.020420
# 95                 False  4.817490
# 33                  True  0.059096

# %%
rush_2021_df.sort_values(by='delta', ascending=False).head(36)
# Out:
#         gsis_id rusher_player_name  season_rush_td_total  expected_touchdowns  \
# 95   00-0035657           D.Harris                  15.0            10.182510
# 82   00-0035243          M.Sanders                   0.0             4.642820
# 77   00-0034845           S.Michel                   4.0             8.184262
# 39   00-0033553           J.Conner                  16.0            11.979580
# 45   00-0033893             D.Cook                   6.0             9.851637
# 47   00-0033906           A.Kamara                   4.0             7.757386
# 148  00-0036997         J.Williams                   4.0             7.032496
# 88   00-0035311           M.Gaskin                   3.0             5.839788
# 70   00-0034750            R.Penny                   6.0             3.180518
# 16   00-0032058          T.Coleman                   0.0             2.797606
# 1    00-0027966           M.Ingram                   2.0             4.670723
# 59   00-0034301        Da.Williams                   6.0             8.499944
# 117  00-0036328           A.Gibson                   7.0             9.463675
# 146  00-0036924          Mi.Carter                   4.0             6.345240
# 122  00-0036414            C.Akers                   0.0             2.237425
# 35   00-0033280        C.McCaffrey                   1.0             3.213239
# 145  00-0036919         K.Gainwell                   5.0             2.813598
# 41   00-0033699           A.Ekeler                  12.0             9.853878
# 26   00-0032764            D.Henry                  11.0             8.875110
# 30   00-0032972           D.Booker                   2.0             4.086063
# 7    00-0030513           L.Murray                   6.0             3.939416
# 83   00-0035250       D.Singletary                  10.0             7.944062
# 36   00-0033293            A.Jones                   4.0             6.036234
# 63   00-0034414            B.Scott                   8.0             6.095952
# 69   00-0034681          C.Edmonds                   2.0             3.794826
# 50   00-0033948         J.Williams                   3.0             4.732347
# 135  00-0036670        J.Jefferson                   2.0             0.288343
# 128  00-0036555          C.Hubbard                   5.0             3.319816
# 102  00-0035831         J.Robinson                   8.0             6.459262
# 40   00-0033594           C.Carson                   3.0             1.508892
# 48   00-0033923             K.Hunt                   5.0             3.566545
# 15   00-0031806            M.Brown                   1.0             2.389980
# 10   00-0031045             C.Hyde                   1.0             2.365521
# 91   00-0035537          T.Johnson                   2.0             3.360488
# 120  00-0036370           J.Kelley                   0.0             1.322624
# 61   00-0034367            N.Hines                   2.0             0.721060
#
#      positive_regression     delta
# 95                 False  4.817490
# 82                  True  4.642820
# 77                  True  4.184262
# 39                 False  4.020420
# 45                  True  3.851637
# 47                  True  3.757386
# 148                 True  3.032496
# 88                  True  2.839788
# 70                 False  2.819482
# 16                  True  2.797606
# 1                   True  2.670723
# 59                  True  2.499944
# 117                 True  2.463675
# 146                 True  2.345240
# 122                 True  2.237425
# 35                  True  2.213239
# 145                False  2.186402
# 41                 False  2.146122
# 26                 False  2.124890
# 30                  True  2.086063
# 7                  False  2.060584
# 83                 False  2.055938
# 36                  True  2.036234
# 63                 False  1.904048
# 69                  True  1.794826
# 50                  True  1.732347
# 135                False  1.711657
# 128                False  1.680184
# 102                False  1.540738
# 40                 False  1.491108
# 48                 False  1.433455
# 15                  True  1.389980
# 10                  True  1.365521
# 91                  True  1.360488
# 120                 True  1.322624
# 61                 False  1.278940

# %%
fig, ax = plt.subplots(figsize=(12,8))
sns.scatterplot(
    data = rush_2021_df,
    x = 'expected_touchdowns',
    y = 'season_rush_td_total',
    hue = 'positive_regression',
    palette= ['red', 'green'],
    s=50
);

max_actual = int(rush_2021_df['season_rush_td_total'].max())
max_expected = int(rush_2021_df['expected_touchdowns'].max())

max_td = max(max_actual, max_expected)

sns.lineplot(range(max_td), range(max_td), alpha = 0.5)

# top_deltas = rush_2021_df.sort_values(by='delta', ascending = False)[:5]

player_array = ['D.Harris', 'M.Sanders', 'S.Michel', 'J.Conner', 'D.Cook', 'D.Singletary', 'A.Gibson', 'A.Ekeler']

for index, row in rush_2021_df.iterrows():
    if row['rusher_player_name'] in player_array:
        ax.text(
            x = row['expected_touchdowns'] +.1,
            y = row['season_rush_td_total'] +0.05,
            s = row['rusher_player_name'],
            fontsize = 12
        )
ax.get_legend().remove()
ax.set_title ('2022 RB Rush TD Regression', fontsize =20)
ax.set_xlabel('Expected Rushing Touchdowns', fontsize =16)
ax.set_ylabel('Actual Rushing TD for 2021 Season', fontsize =16)
# Out:
# /Users/brandynklee/Python_Projects/fantasy_footballl_22/venv/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Actual Rushing TD for 2021 Season')
